# %%
import pickle

result_dict = pickle.load(open("./test.pkl", "rb"))   # 从输出pickle中读取数据

# %%
result_dict.keys()
# Out:
# dict_keys(['summary', 'stock_account', 'trades', 'stock_positions', 'benchmark_portfolio', 'portfolio'])

# %%
result_dict["portfolio"]
# Out:
#             avg_price  last_price  market_value order_book_id  quantity symbol
# date
# 2018-02-02      14.05       14.05       99755.0   000001.XSHE      7100   平安银行
# 2018-02-05      36.99       36.99       99873.0   000002.XSHE      2700    万科A
# 2018-02-05      14.05       14.55           0.0   000001.XSHE         0   平安银行
# 2018-02-06      36.99       35.82           0.0   000002.XSHE         0    万科A
# 2018-02-06      14.00       14.00       99400.0   000001.XSHE      7100   平安银行
# 2018-02-07      32.98       32.98       89046.0   000002.XSHE      2700    万科A
# 2018-02-07      14.00       12.92           0.0   000001.XSHE         0   平安银行
# 2018-02-08      32.98       32.75           0.0   000002.XSHE         0    万科A
# 2018-02-08      12.54       12.54       90288.0   000001.XSHE      7200   平安银行
# 2018-02-09      31.27       31.27       84429.0   000002.XSHE      2700    万科A
# 2018-02-09      12.54       11.69           0.0   000001.XSHE         0   平安银行
# ...

# %%
result_dict["trades"]
# Out:
#                      commission     exec_id  last_price  last_quantity  \
# datetime
# 2018-02-02 09:30:00     79.0088  1523598566       13.91           7100
# 2018-02-05 09:30:00     78.3840  1523598567       13.80           7100
# 2018-02-05 09:30:00     76.5440  1523598568       36.80           2600
# 2018-02-06 09:30:00     74.7344  1523598569       35.93           2600
# 2018-02-06 09:30:00     76.2728  1523598570       14.23           6700
# 2018-02-07 09:30:00     76.2192  1523598571       14.22           6700
# 2018-02-07 09:30:00     75.7744  1523598572       36.43           2600
# 2018-02-08 09:30:00     68.6400  1523598573       33.00           2600
# 2018-02-08 09:30:00     68.7688  1523598574       12.83           6700
# 2018-02-09 09:30:00     64.7488  1523598575       12.08           6700
# 2018-02-09 09:30:00     63.0000  1523598576       31.50           2500
# 2018-02-12 09:30:00     62.8600  1523598577       31.43           2500
# ...

# %%
"1" in ["3","2"]
# Out:
# False
